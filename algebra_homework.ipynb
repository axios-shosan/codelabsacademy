# %% [markdown]
# <a href="https://colab.research.google.com/github/axios-shosan/codelabsacademy/blob/master/algebra_homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Read image

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
  
# Read Images
img = mpimg.imread('me.jpeg')
  
# Output Images
plt.imshow(img)

# %% [markdown]
# # 1st question

# %%
import numpy as np

# %%
img_matrix = np.array(img)

# %%
transpose = img_matrix.T

# %%
transpose
# Out:
# array([[[140, 139, 139, ..., 181, 182, 183],
#         [140, 139, 139, ..., 181, 182, 183],
#         [140, 139, 139, ..., 181, 182, 183],
#         ...,
#         [156, 156, 156, ..., 182, 180, 177],
#         [156, 156, 156, ..., 181, 180, 180],
#         [155, 156, 156, ..., 179, 180, 181]],
#
#        [[141, 140, 140, ..., 183, 184, 185],
#         [141, 140, 140, ..., 183, 184, 185],
#         [141, 140, 140, ..., 183, 184, 185],
#         ...,
#         [156, 156, 156, ..., 187, 185, 182],
#         [156, 156, 156, ..., 186, 185, 185],
#         [155, 156, 156, ..., 184, 185, 186]],
#
#        [[133, 132, 132, ..., 180, 181, 182],
#         [133, 132, 132, ..., 180, 181, 182],
#         [133, 132, 132, ..., 180, 181, 182],
#         ...,
#         [156, 156, 156, ..., 183, 181, 178],
#         [156, 156, 156, ..., 182, 181, 181],
#         [155, 156, 156, ..., 180, 181, 182]]], dtype=uint8)

# %% [markdown]
# # 3rd question

# %%
from numpy.linalg import norm

# %%
l1 = norm(img_matrix[1],1)
l1
# Out:
# 118403.0

# %%
l2 = norm(img_matrix[1])
l2
# Out:
# 7154.293885492823
